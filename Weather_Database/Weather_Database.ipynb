# %%
# Import the dependencies
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combination
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)

# Pack each pair by index into a tuple
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city with citipy
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count
len(cities)
# Out:
# 765

# %%
# Import the requests library
import requests

# Import the API key
from config import weather_api_key

# Import time library to pause every 60sec
import time

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrival   ")
print("--------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i>=50):
        set_count +=1
        record_count = 1
        time.sleep(60)
    
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #Add 1 to the record count
    record_count += 1

# Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_weather_description = city_weather ["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_date list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_weather_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
        
# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        continue

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrival
# --------------------------
# Processing Record 1 of Set 1 | tuggurt
# City not found. Skipping...
# Processing Record 2 of Set 1 | kirkuk
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | xuddur
# Processing Record 6 of Set 1 | codrington
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | shingu
# Processing Record 9 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 1 | pachino
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | aklavik
# Processing Record 17 of Set 1 | victor harbor
# Processing Record 18 of Set 1 | new norfolk
# Processing Record 19 of Set 1 | karakose
# City not found. Skipping...
# Processing Record 20 of Set 1 | saldanha
# Processing Record 21 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 1 | zhezkazgan
# Processing Record 23 of Set 1 | nikolskoye
# Processing Record 24 of Set 1 | carnarvon
# Processing Record 25 of Set 1 | yasnyy
# Processing Record 26 of Set 1 | saskylakh
# Processing Record 27 of Set 1 | hithadhoo
# Processing Record 28 of Set 1 | kadykchan
# City not found. Skipping...
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | longyearbyen
# Processing Record 31 of Set 1 | ljungby
# Processing Record 32 of Set 1 | port elizabeth
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | provideniya
# Processing Record 35 of Set 1 | kaitangata
# Processing Record 36 of Set 1 | goryachiy klyuch
# Processing Record 37 of Set 1 | la ronge
# Processing Record 38 of Set 1 | djambala
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | qaanaaq
# Processing Record 41 of Set 1 | namibe
# Processing Record 42 of Set 1 | ribeira grande
# Processing Record 43 of Set 1 | show low
# Processing Record 44 of Set 1 | morant bay
# Processing Record 45 of Set 1 | rosh pinna
# Processing Record 46 of Set 1 | mentok
# City not found. Skipping...
# Processing Record 47 of Set 1 | bluefield
# Processing Record 48 of Set 1 | haines junction
# Processing Record 49 of Set 1 | hilo
# Processing Record 50 of Set 1 | saint george
# Processing Record 1 of Set 2 | chara
# Processing Record 2 of Set 2 | muravlenko
# Processing Record 3 of Set 2 | cherskiy
# Processing Record 4 of Set 2 | mezhdurechensk
# Processing Record 5 of Set 2 | matay
# Processing Record 6 of Set 2 | yanam
# Processing Record 7 of Set 2 | talnakh
# Processing Record 8 of Set 2 | narsaq
# Processing Record 9 of Set 2 | tiksi
# Processing Record 10 of Set 2 | cidreira
# Processing Record 11 of Set 2 | cape town
# Processing Record 12 of Set 2 | sakaiminato
# Processing Record 13 of Set 2 | vyazemskiy
# Processing Record 14 of Set 2 | adrar
# Processing Record 15 of Set 2 | busselton
# Processing Record 16 of Set 2 | opuwo
# Processing Record 17 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 2 | bengkulu
# Processing Record 19 of Set 2 | east london
# Processing Record 20 of Set 2 | puerto ayora
# Processing Record 21 of Set 2 | alice springs
# Processing Record 22 of Set 2 | asilah
# Processing Record 23 of Set 2 | barrow
# Processing Record 24 of Set 2 | touros
# Processing Record 25 of Set 2 | kapaa
# Processing Record 26 of Set 2 | tagusao
# Processing Record 27 of Set 2 | ordzhonikidze
# Processing Record 28 of Set 2 | bubaque
# Processing Record 29 of Set 2 | leningradskiy
# Processing Record 30 of Set 2 | san patricio
# Processing Record 31 of Set 2 | kijang
# Processing Record 32 of Set 2 | bethel
# Processing Record 33 of Set 2 | tayu
# Processing Record 34 of Set 2 | teacapan
# Processing Record 35 of Set 2 | lucapa
# Processing Record 36 of Set 2 | savasleyka
# Processing Record 37 of Set 2 | norman wells
# Processing Record 38 of Set 2 | muisne
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | gezing
# Processing Record 41 of Set 2 | caldwell
# Processing Record 42 of Set 2 | omboue
# Processing Record 43 of Set 2 | jamestown
# Processing Record 44 of Set 2 | mahebourg
# Processing Record 45 of Set 2 | thinadhoo
# Processing Record 46 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 2 | dhidhdhoo
# Processing Record 48 of Set 2 | port blair
# Processing Record 49 of Set 2 | boende
# Processing Record 50 of Set 2 | georgetown
# Processing Record 1 of Set 3 | khatanga
# Processing Record 2 of Set 3 | san cristobal
# Processing Record 3 of Set 3 | laukaa
# Processing Record 4 of Set 3 | saint anthony
# Processing Record 5 of Set 3 | albany
# Processing Record 6 of Set 3 | tawkar
# City not found. Skipping...
# Processing Record 7 of Set 3 | nacala
# Processing Record 8 of Set 3 | camana
# Processing Record 9 of Set 3 | coihaique
# Processing Record 10 of Set 3 | thompson
# Processing Record 11 of Set 3 | pangody
# Processing Record 12 of Set 3 | te anau
# Processing Record 13 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 3 | torbay
# Processing Record 15 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 3 | lata
# Processing Record 17 of Set 3 | lebu
# Processing Record 18 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 3 | cap-aux-meules
# Processing Record 20 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 3 | grand gaube
# Processing Record 22 of Set 3 | rostock
# Processing Record 23 of Set 3 | atuona
# Processing Record 24 of Set 3 | buraydah
# Processing Record 25 of Set 3 | cooma
# Processing Record 26 of Set 3 | fort nelson
# Processing Record 27 of Set 3 | tasiilaq
# Processing Record 28 of Set 3 | bilozerka
# Processing Record 29 of Set 3 | chuy
# Processing Record 30 of Set 3 | kamaishi
# Processing Record 31 of Set 3 | yertarskiy
# Processing Record 32 of Set 3 | mercedes
# Processing Record 33 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 3 | aqtobe
# Processing Record 35 of Set 3 | klaksvik
# Processing Record 36 of Set 3 | roma
# Processing Record 37 of Set 3 | mae sai
# Processing Record 38 of Set 3 | souillac
# Processing Record 39 of Set 3 | ponta delgada
# Processing Record 40 of Set 3 | shenjiamen
# Processing Record 41 of Set 3 | port macquarie
# Processing Record 42 of Set 3 | nyagan
# Processing Record 43 of Set 3 | mombetsu
# Processing Record 44 of Set 3 | clonakilty
# Processing Record 45 of Set 3 | nabire
# Processing Record 46 of Set 3 | lavrentiya
# Processing Record 47 of Set 3 | poum
# Processing Record 48 of Set 3 | hasaki
# Processing Record 49 of Set 3 | pangani
# Processing Record 50 of Set 3 | victoria
# Processing Record 1 of Set 4 | ponta do sol
# Processing Record 2 of Set 4 | kahului
# Processing Record 3 of Set 4 | savannah bight
# Processing Record 4 of Set 4 | biloela
# Processing Record 5 of Set 4 | sept-iles
# Processing Record 6 of Set 4 | puerto maldonado
# Processing Record 7 of Set 4 | krivosheino
# Processing Record 8 of Set 4 | mae chan
# Processing Record 9 of Set 4 | lorengau
# Processing Record 10 of Set 4 | sangar
# Processing Record 11 of Set 4 | shubarkuduk
# Processing Record 12 of Set 4 | arlit
# Processing Record 13 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 14 of Set 4 | nanton
# Processing Record 15 of Set 4 | khani
# Processing Record 16 of Set 4 | kyenjojo
# Processing Record 17 of Set 4 | olafsvik
# Processing Record 18 of Set 4 | zelenogradsk
# Processing Record 19 of Set 4 | patiya
# Processing Record 20 of Set 4 | constitucion
# Processing Record 21 of Set 4 | tuktoyaktuk
# Processing Record 22 of Set 4 | fairbanks
# Processing Record 23 of Set 4 | dunedin
# Processing Record 24 of Set 4 | high level
# Processing Record 25 of Set 4 | naryan-mar
# Processing Record 26 of Set 4 | mezen
# Processing Record 27 of Set 4 | lincoln
# Processing Record 28 of Set 4 | paveh
# Processing Record 29 of Set 4 | dryden
# Processing Record 30 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 4 | palmer
# Processing Record 32 of Set 4 | cayeli
# Processing Record 33 of Set 4 | gonda
# Processing Record 34 of Set 4 | kyzyl-mazhalyk
# Processing Record 35 of Set 4 | brae
# Processing Record 36 of Set 4 | carballo
# Processing Record 37 of Set 4 | dingle
# Processing Record 38 of Set 4 | lagoa
# Processing Record 39 of Set 4 | xam nua
# Processing Record 40 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 4 | dikson
# Processing Record 42 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 4 | iqaluit
# Processing Record 44 of Set 4 | bonga
# Processing Record 45 of Set 4 | kodiak
# Processing Record 46 of Set 4 | carupano
# Processing Record 47 of Set 4 | berlevag
# Processing Record 48 of Set 4 | gat
# Processing Record 49 of Set 4 | saint-philippe
# Processing Record 50 of Set 4 | brigham city
# Processing Record 1 of Set 5 | nanortalik
# Processing Record 2 of Set 5 | plaster rock
# Processing Record 3 of Set 5 | ormara
# Processing Record 4 of Set 5 | casper
# Processing Record 5 of Set 5 | teya
# Processing Record 6 of Set 5 | comodoro rivadavia
# Processing Record 7 of Set 5 | butaritari
# Processing Record 8 of Set 5 | sao joao da barra
# Processing Record 9 of Set 5 | arraial do cabo
# Processing Record 10 of Set 5 | port hardy
# Processing Record 11 of Set 5 | nantucket
# Processing Record 12 of Set 5 | galle
# Processing Record 13 of Set 5 | luderitz
# Processing Record 14 of Set 5 | la paz
# Processing Record 15 of Set 5 | linxia
# Processing Record 16 of Set 5 | san andres
# Processing Record 17 of Set 5 | presidencia roque saenz pena
# Processing Record 18 of Set 5 | kavieng
# Processing Record 19 of Set 5 | egvekinot
# Processing Record 20 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 5 | tual
# Processing Record 22 of Set 5 | mar del plata
# Processing Record 23 of Set 5 | kidal
# Processing Record 24 of Set 5 | peleduy
# Processing Record 25 of Set 5 | vire
# Processing Record 26 of Set 5 | wanning
# Processing Record 27 of Set 5 | severo-kurilsk
# Processing Record 28 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 29 of Set 5 | golden
# Processing Record 30 of Set 5 | soe
# Processing Record 31 of Set 5 | havelock
# Processing Record 32 of Set 5 | bend
# Processing Record 33 of Set 5 | anshun
# Processing Record 34 of Set 5 | wakkanai
# Processing Record 35 of Set 5 | bandarbeyla
# Processing Record 36 of Set 5 | gavle
# Processing Record 37 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 5 | sao felix do xingu
# Processing Record 39 of Set 5 | avarua
# Processing Record 40 of Set 5 | taoudenni
# Processing Record 41 of Set 5 | huarmey
# Processing Record 42 of Set 5 | husavik
# Processing Record 43 of Set 5 | sturlic
# Processing Record 44 of Set 5 | muzhi
# Processing Record 45 of Set 5 | ilulissat
# Processing Record 46 of Set 5 | hailey
# Processing Record 47 of Set 5 | madang
# Processing Record 48 of Set 5 | tevaitoa
# Processing Record 49 of Set 5 | bouca
# Processing Record 50 of Set 5 | kamenka
# Processing Record 1 of Set 6 | ketchikan
# Processing Record 2 of Set 6 | kudahuvadhoo
# Processing Record 3 of Set 6 | maracaibo
# Processing Record 4 of Set 6 | derbent
# Processing Record 5 of Set 6 | tungkang
# City not found. Skipping...
# Processing Record 6 of Set 6 | chagoda
# Processing Record 7 of Set 6 | xining
# Processing Record 8 of Set 6 | waitati
# Processing Record 9 of Set 6 | okakarara
# Processing Record 10 of Set 6 | baikunthpur
# Processing Record 11 of Set 6 | lepe
# Processing Record 12 of Set 6 | castro
# Processing Record 13 of Set 6 | gamba
# Processing Record 14 of Set 6 | paamiut
# Processing Record 15 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 6 | acapulco
# Processing Record 17 of Set 6 | leshukonskoye
# Processing Record 18 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 6 | santa ines
# Processing Record 20 of Set 6 | guadalajara
# Processing Record 21 of Set 6 | jati
# Processing Record 22 of Set 6 | fort morgan
# Processing Record 23 of Set 6 | tuatapere
# Processing Record 24 of Set 6 | lazaro cardenas
# Processing Record 25 of Set 6 | bambous virieux
# Processing Record 26 of Set 6 | vanimo
# Processing Record 27 of Set 6 | parfino
# Processing Record 28 of Set 6 | pomabamba
# Processing Record 29 of Set 6 | hibbing
# Processing Record 30 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 31 of Set 6 | broken hill
# Processing Record 32 of Set 6 | vao
# Processing Record 33 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 6 | margate
# Processing Record 35 of Set 6 | gudari
# Processing Record 36 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 37 of Set 6 | bathsheba
# Processing Record 38 of Set 6 | caravelas
# Processing Record 39 of Set 6 | namatanai
# Processing Record 40 of Set 6 | ovada
# Processing Record 41 of Set 6 | daxian
# City not found. Skipping...
# Processing Record 42 of Set 6 | pangai
# Processing Record 43 of Set 6 | dambulla
# Processing Record 44 of Set 6 | gobabis
# Processing Record 45 of Set 6 | suao
# City not found. Skipping...
# Processing Record 46 of Set 6 | mehamn
# Processing Record 47 of Set 6 | longhua
# Processing Record 48 of Set 6 | pacific grove
# Processing Record 49 of Set 6 | huilong
# Processing Record 50 of Set 6 | saint joseph
# Processing Record 1 of Set 7 | vostok
# Processing Record 2 of Set 7 | necochea
# Processing Record 3 of Set 7 | grindavik
# Processing Record 4 of Set 7 | caxito
# Processing Record 5 of Set 7 | hofn
# Processing Record 6 of Set 7 | taitung
# Processing Record 7 of Set 7 | sitka
# Processing Record 8 of Set 7 | sur
# Processing Record 9 of Set 7 | okha
# Processing Record 10 of Set 7 | upernavik
# Processing Record 11 of Set 7 | kentau
# Processing Record 12 of Set 7 | nouakchott
# Processing Record 13 of Set 7 | stokmarknes
# Processing Record 14 of Set 7 | jorhat
# Processing Record 15 of Set 7 | anito
# Processing Record 16 of Set 7 | dashitou
# Processing Record 17 of Set 7 | puerto penasco
# Processing Record 18 of Set 7 | isangel
# Processing Record 19 of Set 7 | eyl
# Processing Record 20 of Set 7 | verkhoyansk
# Processing Record 21 of Set 7 | alekseyevka
# Processing Record 22 of Set 7 | pevek
# Processing Record 23 of Set 7 | koumac
# Processing Record 24 of Set 7 | sar-e pul
# Processing Record 25 of Set 7 | auki
# Processing Record 26 of Set 7 | beaupre
# Processing Record 27 of Set 7 | sahrak
# City not found. Skipping...
# Processing Record 28 of Set 7 | akdepe
# Processing Record 29 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 30 of Set 7 | clyde river
# Processing Record 31 of Set 7 | damietta
# Processing Record 32 of Set 7 | richards bay
# Processing Record 33 of Set 7 | kruisfontein
# Processing Record 34 of Set 7 | flinders
# Processing Record 35 of Set 7 | eskisehir
# Processing Record 36 of Set 7 | flin flon
# Processing Record 37 of Set 7 | pizarro
# Processing Record 38 of Set 7 | aden
# Processing Record 39 of Set 7 | viedma
# Processing Record 40 of Set 7 | anadyr
# Processing Record 41 of Set 7 | marsh harbour
# Processing Record 42 of Set 7 | chokurdakh
# Processing Record 43 of Set 7 | mae hong son
# Processing Record 44 of Set 7 | lukovetskiy
# Processing Record 45 of Set 7 | ulladulla
# Processing Record 46 of Set 7 | agadez
# Processing Record 47 of Set 7 | jalu
# Processing Record 48 of Set 7 | iquique
# Processing Record 49 of Set 7 | broome
# Processing Record 50 of Set 7 | salmas
# Processing Record 1 of Set 8 | marand
# Processing Record 2 of Set 8 | nchelenge
# Processing Record 3 of Set 8 | kattivakkam
# Processing Record 4 of Set 8 | duartina
# Processing Record 5 of Set 8 | amalapuram
# Processing Record 6 of Set 8 | geraldton
# Processing Record 7 of Set 8 | faya
# Processing Record 8 of Set 8 | havre-saint-pierre
# Processing Record 9 of Set 8 | san javier
# Processing Record 10 of Set 8 | filingue
# Processing Record 11 of Set 8 | dutse
# Processing Record 12 of Set 8 | saint-francois
# Processing Record 13 of Set 8 | zhigansk
# Processing Record 14 of Set 8 | indianola
# Processing Record 15 of Set 8 | taloqan
# Processing Record 16 of Set 8 | wajir
# Processing Record 17 of Set 8 | medina
# Processing Record 18 of Set 8 | aljezur
# Processing Record 19 of Set 8 | valparaiso
# Processing Record 20 of Set 8 | jaguey grande
# Processing Record 21 of Set 8 | da-an
# City not found. Skipping...
# Processing Record 22 of Set 8 | hede
# Processing Record 23 of Set 8 | coulihaut
# City not found. Skipping...
# Processing Record 24 of Set 8 | ekhabi
# Processing Record 25 of Set 8 | beaverlodge
# Processing Record 26 of Set 8 | taltal
# Processing Record 27 of Set 8 | mariental
# Processing Record 28 of Set 8 | mizdah
# Processing Record 29 of Set 8 | bell ville
# Processing Record 30 of Set 8 | bairiki
# Processing Record 31 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 8 | roald
# Processing Record 33 of Set 8 | lompoc
# Processing Record 34 of Set 8 | port lincoln
# Processing Record 35 of Set 8 | korla
# Processing Record 36 of Set 8 | yankton
# Processing Record 37 of Set 8 | kholtoson
# Processing Record 38 of Set 8 | tommot
# Processing Record 39 of Set 8 | bereda
# Processing Record 40 of Set 8 | kavaratti
# Processing Record 41 of Set 8 | tamsalu
# Processing Record 42 of Set 8 | maniitsoq
# Processing Record 43 of Set 8 | saint-ambroise
# Processing Record 44 of Set 8 | concarneau
# Processing Record 45 of Set 8 | mustafakemalpasa
# Processing Record 46 of Set 8 | hovd
# Processing Record 47 of Set 8 | vila franca do campo
# Processing Record 48 of Set 8 | dera ghazi khan
# Processing Record 49 of Set 8 | airai
# Processing Record 50 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 1 of Set 9 | nortelandia
# Processing Record 2 of Set 9 | ouadda
# Processing Record 3 of Set 9 | charcas
# Processing Record 4 of Set 9 | fomboni
# Processing Record 5 of Set 9 | sinnamary
# Processing Record 6 of Set 9 | ranong
# Processing Record 7 of Set 9 | virovitica
# Processing Record 8 of Set 9 | natagaima
# Processing Record 9 of Set 9 | mehriz
# Processing Record 10 of Set 9 | port moresby
# Processing Record 11 of Set 9 | sao filipe
# Processing Record 12 of Set 9 | cabo san lucas
# Processing Record 13 of Set 9 | vardo
# Processing Record 14 of Set 9 | mojo
# Processing Record 15 of Set 9 | acandi
# Processing Record 16 of Set 9 | pusztaszabolcs
# Processing Record 17 of Set 9 | afmadu
# City not found. Skipping...
# Processing Record 18 of Set 9 | mount gambier
# Processing Record 19 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 21 of Set 9 | takanabe
# Processing Record 22 of Set 9 | novo aripuana
# Processing Record 23 of Set 9 | lexington
# Processing Record 24 of Set 9 | kropotkin
# Processing Record 25 of Set 9 | kaka
# Processing Record 26 of Set 9 | sembakung
# Processing Record 27 of Set 9 | buchanan
# Processing Record 28 of Set 9 | katsuura
# Processing Record 29 of Set 9 | vila
# Processing Record 30 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 31 of Set 9 | belaya gora
# Processing Record 32 of Set 9 | horadiz
# Processing Record 33 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 34 of Set 9 | esperance
# Processing Record 35 of Set 9 | barkhan
# Processing Record 36 of Set 9 | burdur
# Processing Record 37 of Set 9 | balikpapan
# Processing Record 38 of Set 9 | pyay
# Processing Record 39 of Set 9 | pitimbu
# Processing Record 40 of Set 9 | oulainen
# Processing Record 41 of Set 9 | muros
# Processing Record 42 of Set 9 | alofi
# Processing Record 43 of Set 9 | yulara
# Processing Record 44 of Set 9 | ramshir
# Processing Record 45 of Set 9 | tazovskiy
# Processing Record 46 of Set 9 | nalut
# Processing Record 47 of Set 9 | nianzishan
# Processing Record 48 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 50 of Set 9 | sao jose da coroa grande
# Processing Record 1 of Set 10 | dalbandin
# Processing Record 2 of Set 10 | imeni poliny osipenko
# Processing Record 3 of Set 10 | coahuayana
# Processing Record 4 of Set 10 | deniliquin
# Processing Record 5 of Set 10 | mora
# Processing Record 6 of Set 10 | edson
# Processing Record 7 of Set 10 | tadine
# Processing Record 8 of Set 10 | sobolevo
# Processing Record 9 of Set 10 | soure
# Processing Record 10 of Set 10 | mazagao
# Processing Record 11 of Set 10 | cayenne
# Processing Record 12 of Set 10 | sawakin
# Processing Record 13 of Set 10 | farah
# Processing Record 14 of Set 10 | ancud
# Processing Record 15 of Set 10 | san vicente
# Processing Record 16 of Set 10 | mecca
# Processing Record 17 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 10 | rayong
# Processing Record 20 of Set 10 | bongandanga
# Processing Record 21 of Set 10 | nouadhibou
# Processing Record 22 of Set 10 | tamiahua
# Processing Record 23 of Set 10 | la tuque
# Processing Record 24 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 10 | padang
# Processing Record 26 of Set 10 | fortuna
# Processing Record 27 of Set 10 | mackenzie
# Processing Record 28 of Set 10 | yarada
# Processing Record 29 of Set 10 | tatarsk
# Processing Record 30 of Set 10 | puebla
# Processing Record 31 of Set 10 | barranco
# Processing Record 32 of Set 10 | abha
# Processing Record 33 of Set 10 | rio hato
# Processing Record 34 of Set 10 | wisconsin rapids
# Processing Record 35 of Set 10 | sahuaripa
# Processing Record 36 of Set 10 | nome
# Processing Record 37 of Set 10 | giarre
# Processing Record 38 of Set 10 | pangnirtung
# Processing Record 39 of Set 10 | olga
# Processing Record 40 of Set 10 | rio pardo de minas
# Processing Record 41 of Set 10 | entrerrios
# Processing Record 42 of Set 10 | orange cove
# Processing Record 43 of Set 10 | najran
# Processing Record 44 of Set 10 | ferreiras
# Processing Record 45 of Set 10 | ende
# Processing Record 46 of Set 10 | usogorsk
# Processing Record 47 of Set 10 | impfondo
# Processing Record 48 of Set 10 | hokitika
# Processing Record 49 of Set 10 | dicabisagan
# Processing Record 50 of Set 10 | safranbolu
# Processing Record 1 of Set 11 | scarborough
# Processing Record 2 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 3 of Set 11 | russell
# Processing Record 4 of Set 11 | faanui
# Processing Record 5 of Set 11 | waipawa
# Processing Record 6 of Set 11 | sioux lookout
# Processing Record 7 of Set 11 | shiliguri
# Processing Record 8 of Set 11 | orlik
# Processing Record 9 of Set 11 | nioaque
# Processing Record 10 of Set 11 | olmos
# Processing Record 11 of Set 11 | komsomolskiy
# Processing Record 12 of Set 11 | ocampo
# Processing Record 13 of Set 11 | terrasini
# Processing Record 14 of Set 11 | santiago de cao
# Processing Record 15 of Set 11 | madoc
# Processing Record 16 of Set 11 | yinchuan
# Processing Record 17 of Set 11 | jijiga
# Processing Record 18 of Set 11 | asuncion
# Processing Record 19 of Set 11 | ariquemes
# Processing Record 20 of Set 11 | gawler
# Processing Record 21 of Set 11 | bainbridge
# Processing Record 22 of Set 11 | guerrero negro
# Processing Record 23 of Set 11 | mingshui
# Processing Record 24 of Set 11 | marondera
# Processing Record 25 of Set 11 | gulshat
# City not found. Skipping...
# Processing Record 26 of Set 11 | forbes
# Processing Record 27 of Set 11 | port augusta
# Processing Record 28 of Set 11 | tiarei
# Processing Record 29 of Set 11 | ginir
# Processing Record 30 of Set 11 | elizabeth city
# Processing Record 31 of Set 11 | along
# Processing Record 32 of Set 11 | vila velha
# Processing Record 33 of Set 11 | maraa
# Processing Record 34 of Set 11 | chimbote
# Processing Record 35 of Set 11 | rodrigues alves
# Processing Record 36 of Set 11 | naze
# Processing Record 37 of Set 11 | hami
# Processing Record 38 of Set 11 | thouars
# Processing Record 39 of Set 11 | jalapa
# Processing Record 40 of Set 11 | tatvan
# Processing Record 41 of Set 11 | kuryk
# Processing Record 42 of Set 11 | mackay
# Processing Record 43 of Set 11 | morros
# Processing Record 44 of Set 11 | yerbogachen
# Processing Record 45 of Set 11 | thanh hoa
# Processing Record 46 of Set 11 | san jose de guanipa
# Processing Record 47 of Set 11 | los llanos de aridane
# Processing Record 48 of Set 11 | salalah
# Processing Record 49 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 50 of Set 11 | puerto colombia
# Processing Record 1 of Set 12 | yar-sale
# Processing Record 2 of Set 12 | kampene
# Processing Record 3 of Set 12 | montbrison
# Processing Record 4 of Set 12 | tabuleiro do norte
# Processing Record 5 of Set 12 | christchurch
# Processing Record 6 of Set 12 | rocha
# Processing Record 7 of Set 12 | talaya
# Processing Record 8 of Set 12 | umm kaddadah
# Processing Record 9 of Set 12 | nadbai
# Processing Record 10 of Set 12 | matara
# Processing Record 11 of Set 12 | bambanglipuro
# Processing Record 12 of Set 12 | hervey bay
# Processing Record 13 of Set 12 | darab
# Processing Record 14 of Set 12 | coxim
# Processing Record 15 of Set 12 | verkhnevilyuysk
# Processing Record 16 of Set 12 | hohhot
# Processing Record 17 of Set 12 | jinka
# Processing Record 18 of Set 12 | baykit
# Processing Record 19 of Set 12 | waw
# Processing Record 20 of Set 12 | camalu
# Processing Record 21 of Set 12 | abhar
# Processing Record 22 of Set 12 | dossor
# Processing Record 23 of Set 12 | dwarka
# Processing Record 24 of Set 12 | porto novo
# Processing Record 25 of Set 12 | hobyo
# Processing Record 26 of Set 12 | saint-paul
# Processing Record 27 of Set 12 | yershichi
# Processing Record 28 of Set 12 | zhaotong
# Processing Record 29 of Set 12 | yanaul
# Processing Record 30 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 31 of Set 12 | puerto del rosario
# Processing Record 32 of Set 12 | lokosovo
# Processing Record 33 of Set 12 | asau
# Processing Record 34 of Set 12 | liberal
# Processing Record 35 of Set 12 | keratea
# Processing Record 36 of Set 12 | mulanje
# Processing Record 37 of Set 12 | mersing
# Processing Record 38 of Set 12 | algiers
# Processing Record 39 of Set 12 | tagbac
# Processing Record 40 of Set 12 | banda aceh
# Processing Record 41 of Set 12 | meulaboh
# Processing Record 42 of Set 12 | prescott
# Processing Record 43 of Set 12 | sidi bu zayd
# City not found. Skipping...
# Processing Record 44 of Set 12 | mount isa
# Processing Record 45 of Set 12 | athens
# Processing Record 46 of Set 12 | juifang
# City not found. Skipping...
# Processing Record 47 of Set 12 | boyolangu
# Processing Record 48 of Set 12 | jibuti
# Processing Record 49 of Set 12 | kurilsk
# Processing Record 50 of Set 12 | college
# Processing Record 1 of Set 13 | tocopilla
# Processing Record 2 of Set 13 | coro
# Processing Record 3 of Set 13 | kaeo
# Processing Record 4 of Set 13 | pisco
# Processing Record 5 of Set 13 | milazzo
# Processing Record 6 of Set 13 | lujan
# Processing Record 7 of Set 13 | homer
# Processing Record 8 of Set 13 | kilinochchi
# Processing Record 9 of Set 13 | bam
# Processing Record 10 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 11 of Set 13 | samarai
# Processing Record 12 of Set 13 | abu jubayhah
# City not found. Skipping...
# Processing Record 13 of Set 13 | lasa
# Processing Record 14 of Set 13 | basarabeasca
# Processing Record 15 of Set 13 | beringovskiy
# Processing Record 16 of Set 13 | port hedland
# Processing Record 17 of Set 13 | miraflores
# Processing Record 18 of Set 13 | tateyama
# Processing Record 19 of Set 13 | polyarnyye zori
# Processing Record 20 of Set 13 | sarangani
# Processing Record 21 of Set 13 | matane
# Processing Record 22 of Set 13 | kirpilskaya
# Processing Record 23 of Set 13 | ligayan
# Processing Record 24 of Set 13 | turkan
# Processing Record 25 of Set 13 | izhma
# Processing Record 26 of Set 13 | mogadishu
# Processing Record 27 of Set 13 | kawalu
# Processing Record 28 of Set 13 | tolaga bay
# Processing Record 29 of Set 13 | maceio
# Processing Record 30 of Set 13 | laguna
# Processing Record 31 of Set 13 | bangolo
# Processing Record 32 of Set 13 | lamu
# Processing Record 33 of Set 13 | kedrovoye
# Processing Record 34 of Set 13 | shebunino
# Processing Record 35 of Set 13 | itarema
# Processing Record 36 of Set 13 | trairi
# Processing Record 37 of Set 13 | santa cruz cabralia
# Processing Record 38 of Set 13 | jiwani
# Processing Record 39 of Set 13 | panaba
# Processing Record 40 of Set 13 | yaransk
# Processing Record 41 of Set 13 | moerai
# Processing Record 42 of Set 13 | oktyabrskoye
# Processing Record 43 of Set 13 | san policarpo
# Processing Record 44 of Set 13 | lakes entrance
# Processing Record 45 of Set 13 | murray bridge
# Processing Record 46 of Set 13 | murgab
# Processing Record 47 of Set 13 | passo fundo
# Processing Record 48 of Set 13 | kabakovo
# Processing Record 49 of Set 13 | naifaru
# Processing Record 50 of Set 13 | san ramon
# Processing Record 1 of Set 14 | rio grande
# Processing Record 2 of Set 14 | gigmoto
# Processing Record 3 of Set 14 | manicore
# Processing Record 4 of Set 14 | baruun-urt
# Processing Record 5 of Set 14 | malakal
# Processing Record 6 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 14 | oparino
# Processing Record 8 of Set 14 | anar darreh
# City not found. Skipping...
# Processing Record 9 of Set 14 | taree
# Processing Record 10 of Set 14 | carazinho
# Processing Record 11 of Set 14 | atar
# Processing Record 12 of Set 14 | saint-georges
# Processing Record 13 of Set 14 | wuwei
# Processing Record 14 of Set 14 | tekeli
# Processing Record 15 of Set 14 | tuljapur
# Processing Record 16 of Set 14 | san quintin
# Processing Record 17 of Set 14 | danville
# Processing Record 18 of Set 14 | san bernardo
# Processing Record 19 of Set 14 | kuhestan
# City not found. Skipping...
# Processing Record 20 of Set 14 | inhambane
# Processing Record 21 of Set 14 | kirakira
# Processing Record 22 of Set 14 | satrikh
# Processing Record 23 of Set 14 | miharu
# Processing Record 24 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 25 of Set 14 | boffa
# Processing Record 26 of Set 14 | hearst
# Processing Record 27 of Set 14 | traralgon
# Processing Record 28 of Set 14 | great falls
# Processing Record 29 of Set 14 | sakakah
# Processing Record 30 of Set 14 | buala
# Processing Record 31 of Set 14 | axim
# Processing Record 32 of Set 14 | evanston
# Processing Record 33 of Set 14 | taburi
# City not found. Skipping...
# Processing Record 34 of Set 14 | almeirim
# Processing Record 35 of Set 14 | coquimbo
# Processing Record 36 of Set 14 | razole
# Processing Record 37 of Set 14 | lakota
# Processing Record 38 of Set 14 | lar
# Processing Record 39 of Set 14 | mawlaik
# Processing Record 40 of Set 14 | sumbe
# Processing Record 41 of Set 14 | cabra
# Processing Record 42 of Set 14 | cockburn town
# Processing Record 43 of Set 14 | kant
# Processing Record 44 of Set 14 | hualmay
# Processing Record 45 of Set 14 | lang suan
# Processing Record 46 of Set 14 | kortkeros
# Processing Record 47 of Set 14 | myingyan
# Processing Record 48 of Set 14 | robertsport
# Processing Record 49 of Set 14 | kobayashi
# Processing Record 50 of Set 14 | yeniseysk
# Processing Record 1 of Set 15 | oranjestad
# Processing Record 2 of Set 15 | skjervoy
# Processing Record 3 of Set 15 | morondava
# Processing Record 4 of Set 15 | andapa
# Processing Record 5 of Set 15 | korcula
# Processing Record 6 of Set 15 | sechura
# Processing Record 7 of Set 15 | mayo
# Processing Record 8 of Set 15 | aksay
# Processing Record 9 of Set 15 | bukavu
# Processing Record 10 of Set 15 | manta
# Processing Record 11 of Set 15 | myszkow
# Processing Record 12 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 13 of Set 15 | kasulu
# Processing Record 14 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 15 | tura
# Processing Record 16 of Set 15 | lemesos
# City not found. Skipping...
# Processing Record 17 of Set 15 | deh rawud
# City not found. Skipping...
# Processing Record 18 of Set 15 | fare
# Processing Record 19 of Set 15 | lakinsk
# Processing Record 20 of Set 15 | agua verde
# Processing Record 21 of Set 15 | asasa
# Processing Record 22 of Set 15 | ampanihy
# Processing Record 23 of Set 15 | gadwal
# Processing Record 24 of Set 15 | north bend
# Processing Record 25 of Set 15 | bellary
# Processing Record 26 of Set 15 | santa maria
# Processing Record 27 of Set 15 | tumkur
# Processing Record 28 of Set 15 | manama
# Processing Record 29 of Set 15 | tir pol
# City not found. Skipping...
# Processing Record 30 of Set 15 | espanola
# Processing Record 31 of Set 15 | bac lieu
# Processing Record 32 of Set 15 | marmora
# Processing Record 33 of Set 15 | karangampel
# Processing Record 34 of Set 15 | savelugu
# Processing Record 35 of Set 15 | lima
# Processing Record 36 of Set 15 | qaqortoq
# Processing Record 37 of Set 15 | biak
# Processing Record 38 of Set 15 | bakchar
# Processing Record 39 of Set 15 | banamba
# Processing Record 40 of Set 15 | mangrol
# Processing Record 41 of Set 15 | novichikha
# Processing Record 42 of Set 15 | mnogovershinnyy
# Processing Record 43 of Set 15 | chapada dos guimaraes
# Processing Record 44 of Set 15 | amambai
# Processing Record 45 of Set 15 | igunga
# Processing Record 46 of Set 15 | posyet
# Processing Record 47 of Set 15 | bogorodskoye
# Processing Record 48 of Set 15 | sorland
# Processing Record 49 of Set 15 | nemuro
# Processing Record 50 of Set 15 | forssa
# Processing Record 1 of Set 16 | waverly
# Processing Record 2 of Set 16 | omaruru
# Processing Record 3 of Set 16 | kazalinsk
# City not found. Skipping...
# Processing Record 4 of Set 16 | araguacu
# Processing Record 5 of Set 16 | shar
# Processing Record 6 of Set 16 | half moon bay
# Processing Record 7 of Set 16 | rognan
# Processing Record 8 of Set 16 | juneau
# Processing Record 9 of Set 16 | bluefields
# Processing Record 10 of Set 16 | cairns
# Processing Record 11 of Set 16 | novopavlovka
# Processing Record 12 of Set 16 | rio cuarto
# Processing Record 13 of Set 16 | moche
# Processing Record 14 of Set 16 | srednekolymsk
# Processing Record 15 of Set 16 | tete
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 701

# %%
# Convert the array of dictionaries to a pd df
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0       Kirkuk  35.4681   44.3922           clear sky     93.92        16
# 1      Rikitea -23.1203 -134.9692    scattered clouds     72.21        65
# 2       Xuddur   4.1213   43.8894     overcast clouds     85.62        35
# 3   Codrington -38.2667  141.9667     overcast clouds     51.21        84
# 4     Hermanus -34.4187   19.2345           clear sky     59.81        78
# 5       Shingu  33.7333  135.9833       broken clouds     76.01        91
# 6      Pachino  36.7186   15.0907    scattered clouds     81.25        79
# 7        Vaini -21.2000 -175.2000       broken clouds     73.56        94
# 8  Port Alfred -33.5906   26.8910          few clouds     65.17        88
# 9       Hobart -42.8794  147.3294     overcast clouds     56.05        94
#
#    Cloudiness  Wind Speed Country
# 0           0        7.20      IQ
# 1          25       21.72      PF
# 2          99       14.50      SO
# 3          96       20.45      AU
# 4           0        3.60      ZA
# 5          77        4.45      JP
# 6          25       14.16      IT
# 7          75        5.75      TO
# 8          20        1.01      ZA
# 9         100        0.00      AU

# %%
column_order  = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Kirkuk      IQ  35.4681   44.3922     93.92        16           0
# 1      Rikitea      PF -23.1203 -134.9692     72.21        65          25
# 2       Xuddur      SO   4.1213   43.8894     85.62        35          99
# 3   Codrington      AU -38.2667  141.9667     51.21        84          96
# 4     Hermanus      ZA -34.4187   19.2345     59.81        78           0
# 5       Shingu      JP  33.7333  135.9833     76.01        91          77
# 6      Pachino      IT  36.7186   15.0907     81.25        79          25
# 7        Vaini      TO -21.2000 -175.2000     73.56        94          75
# 8  Port Alfred      ZA -33.5906   26.8910     65.17        88          20
# 9       Hobart      AU -42.8794  147.3294     56.05        94         100
#
#    Wind Speed Current Description
# 0        7.20           clear sky
# 1       21.72    scattered clouds
# 2       14.50     overcast clouds
# 3       20.45     overcast clouds
# 4        3.60           clear sky
# 5        4.45       broken clouds
# 6       14.16    scattered clouds
# 7        5.75       broken clouds
# 8        1.01          few clouds
# 9        0.00     overcast clouds

# %%
# Create the output file (CSV)
output_file = "WeatherPy_Database.csv"
# Export the city_data intp CSV
city_data_df.to_csv(output_file, index_label = 'City_ID')
